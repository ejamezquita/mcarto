# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import gudhi as gd
import json

from glob import glob
import os
import tifffile as tf

from scipy import ndimage
from sklearn import manifold, cluster

# %%
gsrc = '../gudhi/'
sample = 'B1'
tsrc = gsrc + sample + '/'
transcriptomes = sorted([foo.split('/')[-2] for foo in glob(tsrc + '*/')])
print(len(transcriptomes), 'transcriptomes')
# Out:
# 27 transcriptomes

# %%
wall = 255 - tf.imread('../cell_dams/' + sample + '_dams.tif')
wcoords = np.array(np.nonzero(wall))
#label, cellnum = ndimage.label(wall, ndimage.generate_binary_structure(2,1))
#objss = ndimage.find_objects(label)

# %%
filename = '../data/' + sample + '_data/' + transcriptomes[0] + '/' + transcriptomes[0] + ' - localization results by cell.csv'
print(filename)
df = pd.read_csv(filename)
df = df.iloc[~np.any(df.iloc[:, :5].isnull().values, axis=1)]
df = df.astype({'Cell.ID..':int})
df.head()
# Out:
# ../data/B1_data/CYP93A1/CYP93A1 - localization results by cell.csv
#    Cell.ID..  X.location  Y.location  Bouding.box.X  Bouding.box.Y  \
# 0          0       0.000       0.000            0.0            0.0
# 1          1    7209.574    7213.375            0.0            0.0
# 2          2    2495.503    1067.266         2344.0          905.0
# 3          3    2524.642    1392.115         2064.0          961.0
# 4          4    3136.522    1323.289         2979.0         1131.0
#
#    Bouding.box.width  Bouding.box.height  Cell.Area..px.  Nucleus.Area..px.  \
# 0                0.0                 0.0             0.0        159948015.0
# 1            10720.0             15008.0      63530175.0           182824.0
# 2              271.0               324.0         53837.0                0.0
# 3              961.0               849.0        390626.0             1246.0
# 4              286.0               386.0         69756.0                0.0
#
#    Total.transcript..  ...  Median.distance.from.nucleus.incl..nucleus..px.  \
# 0                66.0  ...                                            202.0
# 1               691.0  ...                                            106.0
# 2                 5.0  ...                                            108.0
# 3                32.0  ...                                            143.0
# 4                 4.0  ...                                            329.0
#
#    Median.distance.from.nucleus.excl..nucleus..px.  \
# 0                                            222.0
# 1                                            142.0
# 2                                            108.0
# 3                                            153.0
# 4                                            329.0
#
#    X1st.quartile.distance.w..nucleus..px.  \
# 0                                   101.0
# 1                                    10.0
# 2                                    91.0
# 3                                    64.0
# 4                                   303.0
#
#    X1st.quartile.distance.w.o.nucleus..px.  \
# 0                                    122.0
# 1                                     68.0
# 2                                     91.0
# 3                                     72.0
# 4                                    303.0
#
#    X3rd.quartile.distance.w..nucleus..px.  \
# 0                                   357.0
# 1                                   216.0
# 2                                   154.0
# 3                                   202.0
# 4                                   381.0
#
#    X3rd.quartile.distance.w.o.nucleus..px.  nuclear.only.transcripts  \
# 0                                    378.0                       5.0
# 1                                    256.0                     142.0
# 2                                    154.0                       0.0
# 3                                    202.0                       1.0
# 4                                    381.0                       0.0
#
#    average.nuclear.transcript.percentage  Total.cells.expressed  Nuc_cells_exp
# 0                                    7.6                    327            122
# 1                                   20.5                    327            122
# 2                                    0.0                    327            122
# 3                                    3.1                    327            122
# 4                                    0.0                    327            122
#
# [5 rows x 24 columns]

# %%
def get_diagrams(jsonfiles):
    diagh0 = [ np.empty((0,2)) for i in range(len(jsonfiles)) ]
    diagh1 = [ np.empty((0,2)) for i in range(len(jsonfiles)) ]

    for i in range(len(jsonfiles)):
        with open(jsonfiles[i]) as f:
            diag = [tuple(x) for x in json.load(f)]
        h1mask = np.sum([ diag[j][0] == 1 for j in range(len(diag)) ])
        diagh0[i] = np.asarray( [ x[1] for x in diag[h1mask:] ] )
        if h1mask > 0:
            diagh1[i] = np.asarray( [ x[1] for x in diag[:h1mask] ] )

    return diagh0, diagh1

def bottleneck_matrix(diagh0, diagh1):
    bottleneck_h0 = np.zeros( (len(diagh0), len(diagh0)) )
    bottleneck_h1 = np.zeros( (len(diagh0), len(diagh0)) )
    
    for i in range(len(bottleneck_h0) - 1):
        for j in range(i+1, len(bottleneck_h0)):
    
            ## H0 ##
            d = gd.bottleneck_distance(diagh0[i], diagh0[j])
            bottleneck_h0[i,j] = d
            bottleneck_h0[j,i] = d
    
            ## H1 ##
            d = gd.bottleneck_distance(diagh1[i], diagh1[j])
            bottleneck_h1[i,j] = d
            bottleneck_h1[j,i] = d
    
    bottleneck = np.where(bottleneck_h0 > bottleneck_h1, bottleneck_h0, bottleneck_h1)

    return bottleneck, bottleneck_h0, bottleneck_h1

# %%
tidx = 4
print(transcriptomes[tidx])
subjsons = sorted(glob(tsrc + transcriptomes[tidx] + '/sublevel*.json'))
print('Cells:', len(subjsons))

filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_suplevel_bottleneck_h1.npy'

if not os.path.isfile(filename):

    supjsons = sorted(glob(tsrc + transcriptomes[tidx] + '/superlevel*.json'))
    subdiagh0, subdiagh1 = get_diagrams(subjsons)
    supdiagh0, supdiagh1 = get_diagrams(supjsons)
    
    subbottle, subbottle_h0, subbottle_h1 = bottleneck_matrix(subdiagh0, subdiagh1)
    supbottle, supbottle_h0, supbottle_h1 = bottleneck_matrix(supdiagh0, supdiagh1)
    
    ## Sublevel persistence ##
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_sublevel_bottleneck_h0.npy'
    np.save(filename, subbottle_h0, allow_pickle=True)
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_sublevel_bottleneck_h1.npy'
    np.save(filename, subbottle_h1, allow_pickle=True)
    
    print(filename)
    
    ## Superlevel persistence ##
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_suplevel_bottleneck_h0.npy'
    np.save(filename, supbottle_h0, allow_pickle=True)
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_suplevel_bottleneck_h1.npy'
    np.save(filename, supbottle_h1, allow_pickle=True)
    
    print(filename)

else:

    ## Sublevel persistence ##
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_sublevel_bottleneck_h0.npy'
    subbottle_h0 = np.load(filename, allow_pickle=True)
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_sublevel_bottleneck_h1.npy'
    subbottle_h1 = np.load(filename, allow_pickle=True)

    subbottle = np.where(subbottle_h0 > subbottle_h1, subbottle_h0, subbottle_h1)

    ## Superlevel persistence ##
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_suplevel_bottleneck_h0.npy'
    supbottle_h0 = np.load(filename, allow_pickle=True)
    filename = tsrc + transcriptomes[tidx] + '/' + transcriptomes[tidx] + '_-_suplevel_bottleneck_h1.npy'
    supbottle_h1 = np.load(filename, allow_pickle=True)

    supbottle = np.where(supbottle_h0 > supbottle_h1, supbottle_h0, supbottle_h1)

mds = manifold.MDS(n_components=2, metric=True, random_state=42, dissimilarity='precomputed', normalized_stress=False)
subX = mds.fit_transform(subbottle)
supX = mds.fit_transform(supbottle)
# Out:
# GLYMA_03G029900
# Cells: 232

# %%
dbscan = cluster.DBSCAN(eps=5, min_samples=2)
supclust = dbscan.fit(supX)
subclust = dbscan.fit(subX)

# %%
color = ['#000000', '#009e73', '#f0e442', '#0072b2', '#cc79a7']
marker = ['*', 'D', 'o', 'X', '^', 'v', 'P']

fs = 16
fig, ax = plt.subplots(1,2, figsize=(12,6))
ax = np.atleast_1d(ax).ravel()

for i,(X,labs) in enumerate(zip([subX, supX], [subclust, supclust])):
    labs = labs.labels_
    ulabs = np.unique(labs)
    for j in range(len(ulabs)):
        mask = labs == ulabs[j]
        ax[i].scatter(X[mask,0], X[mask,1], s=50,
                      c=color[j%len(color)], marker=marker[j%len(marker)], edgecolor='k')
    ax[i].set_aspect('equal', 'datalim');
    ax[i].set_facecolor('snow')

ax[0].set_title('Sublevel set persistence', fontsize=fs)
ax[1].set_title('Superlevel set persistence', fontsize=fs)

fig.supxlabel('MDS 1', fontsize=fs)
fig.supylabel('MDS 2', fontsize=fs)

title = sample + ' - ' + transcriptomes[tidx] + ': {} cells into {} clusters (DBSCAN [$\\varepsilon = $ {}])'.format(len(subjsons), len(ulabs)-1, dbscan.eps)
fig.suptitle(title, fontsize=fs)

fig.tight_layout();

# %%
cellid = [None for i in range(len(ulabs))]
for j in range(len(cellid)):
    mask = np.nonzero(labs == ulabs[j])[0]
    cellid[j] = np.asarray([ os.path.splitext(subjsons[ mask[i] ])[0].split('_-_')[-2:] for i in range(len(mask)) ]).astype(int)

# %%
cellloc = [ np.zeros_like(cellid[i]) for i in range(len(cellid)) ]

for j in range(len(cellloc)):
    for k in range(len(cellloc[j])):
        foo = df[ df['Cell.ID..'] == cellid[j][k,1] ]
        cellloc[j][k] = foo.iloc[0, 1:3].values

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))
ax = np.atleast_1d(ax).ravel()

ax[0].scatter(wcoords[1], wcoords[0], c='gray', marker='.', s=0.01, zorder=1)
for j in range(len(cellloc)):
    ax[0].scatter(cellloc[j][:,0], cellloc[j][:,1], s=50,
                  c=color[j%len(color)], marker=marker[j%len(marker)], edgecolor='k')


ax[0].set_aspect('equal')
ax[0].margins(0)
ax[0].set_facecolor('snow')
fig.tight_layout();
